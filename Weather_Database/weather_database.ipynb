# %%
# Import the random module.
import random
import numpy as np
import pandas as pd
from citipy import citipy
import os
import datetime as dt 
import time
import matplotlib.pyplot as plt

# %%
# Create a new set of 2,000 random latitudes and longitudes.

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# ituni gy
# linxia cn
# samarai pg
# rikitea pf
# vaini to
# ushuaia ar
# george za
# mahebourg mu
# illoqqortoormiut gl
# jamestown sh
# jiayuguan cn
# byron bay au
# kaitangata nz
# moron mn
# hilo us
# samalaeulu ws
# barrow us
# hermanus za
# cherskiy ru
# port alfred za
# robertsport lr
# thompson ca
# katsuura jp
# dikson ru
# hobart au
# aberdeen us
# alice town bs
# punta arenas cl
# trelew ar
# tawkar sd
# ibara jp
# coquimbo cl
# makakilo city us
# jamestown sh
# yellowknife ca
# diu in
# rurrenabaque bo
# nisia floresta br
# punta arenas cl
# rikitea pf
# sisimiut gl
# faanui pf
# mount isa au
# marawi sd
# tuktoyaktuk ca
# lavrentiya ru
# kampot kh
# carutapera br
# bonthe sl
# taolanaro mg
# porto belo br
# rocha uy
# coquimbo cl
# nagato jp
# atambua id
# albany au
# torbay ca
# baiyin cn
# albany au
# cape town za
# port alfred za
# pevek ru
# punta arenas cl
# kapaa us
# cape town za
# bredasdorp za
# busselton au
# faanui pf
# bonfim br
# jamestown sh
# college us
# caravelas br
# acarau br
# albany au
# tuktoyaktuk ca
# tecoanapa mx
# camabatela ao
# jamestown sh
# banda aceh id
# ostrovnoy ru
# vanimo pg
# bluff nz
# ribeira grande pt
# pedernales mx
# pisco pe
# alice springs au
# yaan cn
# taolanaro mg
# esperance au
# guerrero negro mx
# muana br
# warqla dz
# leningradskiy ru
# saint george bm
# mareeba au
# san patricio mx
# illoqqortoormiut gl
# cape town za
# souillac mu
# nuuk gl
# tateyama jp
# millbrook us
# butaritari ki
# kodiak us
# caravelas br
# port lincoln au
# tura ru
# rikitea pf
# portland au
# aitape pg
# apac ug
# kaitangata nz
# sitka us
# goure ne
# souillac mu
# punta arenas cl
# rikitea pf
# berlevag no
# hambantota lk
# upernavik gl
# provideniya ru
# tasiilaq gl
# westport ie
# avarua ck
# touros br
# vaini to
# vaitupu wf
# lakes entrance au
# mataura pf
# tuatapere nz
# castro cl
# rovaniemi fi
# orange cove us
# ostrovnoy ru
# beira mz
# saint anthony ca
# rikitea pf
# albany au
# dikson ru
# rikitea pf
# samusu ws
# inhambane mz
# isangel vu
# tasiilaq gl
# port augusta au
# souillac mu
# dunedin nz
# tuktoyaktuk ca
# vaini to
# rikitea pf
# kalaleh ir
# araouane ml
# balkanabat tm
# barentsburg sj
# nizhneyansk ru
# nanortalik gl
# lehigh acres us
# okha ru
# rikitea pf
# saint-philippe re
# jardim br
# bredasdorp za
# bluff nz
# mataura pf
# eureka us
# surin th
# hailar cn
# vaini to
# taolanaro mg
# palabuhanratu id
# atuona pf
# butaritari ki
# bredasdorp za
# makakilo city us
# srednekolymsk ru
# karaul ru
# mullaitivu lk
# bluff nz
# isangel vu
# beloha mg
# mount gambier au
# nikolskoye ru
# kaitangata nz
# korla cn
# diebougou bf
# ukiah us
# kapaa us
# airai pw
# albany au
# busselton au
# bethel us
# atikokan ca
# barentsburg sj
# buala sb
# chaumont fr
# east london za
# nikolskoye ru
# port hardy ca
# bluff nz
# albany au
# tumannyy ru
# tuatapere nz
# muravlenko ru
# puerto ayora ec
# dikson ru
# phangnga th
# wexford ie
# albany au
# nikolskoye ru
# saint-augustin ca
# bolonchen mx
# cape town za
# trstenik rs
# grindavik is
# thurso gb
# leningradskiy ru
# pisco pe
# batagay-alyta ru
# rungata ki
# honningsvag no
# saint-philippe re
# aklavik ca
# castro cl
# kuna us
# hobart au
# yumen cn
# busselton au
# shenjiamen cn
# chuy uy
# te anau nz
# puerto ayora ec
# saint george bm
# chuy uy
# iqaluit ca
# cayenne gf
# hualmay pe
# hilo us
# nanakuli us
# mataura pf
# atuona pf
# cape town za
# saskylakh ru
# bargal so
# nanortalik gl
# kaitangata nz
# ambunti pg
# clyde river ca
# yarmouth ca
# attawapiskat ca
# hithadhoo mv
# hithadhoo mv
# hilo us
# slantsy ru
# rikitea pf
# pasni pk
# imbituba br
# punta arenas cl
# kirakira sb
# srandakan id
# busselton au
# tambura sd
# hermanus za
# taolanaro mg
# port elizabeth za
# nieuw amsterdam sr
# illoqqortoormiut gl
# bluff nz
# samalaeulu ws
# cape town za
# dzaoudzi yt
# albany au
# rio hato pa
# bengkulu id
# maua ke
# antofagasta cl
# jamestown sh
# busselton au
# hobart au
# hithadhoo mv
# terme tr
# kapaa us
# talcahuano cl
# rikitea pf
# norman wells ca
# goundam ml
# hermanus za
# east london za
# buchanan lr
# aklavik ca
# alekseyevka ru
# kodiak us
# nanortalik gl
# aalst be
# alice springs au
# busselton au
# ilulissat gl
# havoysund no
# mataura pf
# hilo us
# hobart au
# norman wells ca
# artyk ru
# chokurdakh ru
# saskylakh ru
# coihaique cl
# jamestown sh
# vostok ru
# bengkulu id
# port hardy ca
# clyde river ca
# marsa matruh eg
# kempele fi
# hermanus za
# saleaula ws
# kazalinsk kz
# san patricio mx
# sapao ph
# puerto narino co
# tuktoyaktuk ca
# provideniya ru
# rikitea pf
# la reforma mx
# preobrazhenskaya ru
# albany au
# petatlan mx
# los llanos de aridane es
# arraial do cabo br
# inuvik ca
# obo cf
# korla cn
# dulce grande mx
# jamestown sh
# richards bay za
# bluff nz
# bluff nz
# zdvinsk ru
# faxinal br
# ushuaia ar
# puerto ayora ec
# kruisfontein za
# port macquarie au
# narsaq gl
# airai pw
# puerto ayora ec
# muskegon us
# tasiilaq gl
# pevek ru
# busselton au
# ushuaia ar
# kapaa us
# hilo us
# urucara br
# hobart au
# mutsamudu km
# karamea nz
# jamestown sh
# labutta mm
# derventa ba
# coihaique cl
# rikitea pf
# lompoc us
# leningradskiy ru
# busselton au
# jamestown sh
# yulara au
# ajdabiya ly
# ancud cl
# butterworth za
# hobart au
# visnes no
# hovd mn
# nizhneyansk ru
# tigil ru
# albany au
# torbay ca
# mataura pf
# tual id
# jumla np
# arraial do cabo br
# east london za
# chuy uy
# mbalmayo cm
# kodiak us
# luwuk id
# hermanus za
# roald no
# albany au
# sao joao da barra br
# puerto ayora ec
# ushuaia ar
# basco ph
# cairns au
# kavieng pg
# mahebourg mu
# kamenka ru
# arraial do cabo br
# rikitea pf
# vaini to
# palabuhanratu id
# amderma ru
# maldonado uy
# chuy uy
# sorland no
# wangdiphodrang bt
# atuona pf
# tiarei pf
# nishihara jp
# rawson ar
# barrow us
# taolanaro mg
# wulanhaote cn
# annan gb
# barrow us
# dunedin nz
# ponta do sol cv
# puerto ayora ec
# auka hn
# ranot th
# manono cd
# hilo us
# busselton au
# merritt island us
# hamilton bm
# punta arenas cl
# pacific grove us
# najran sa
# bredasdorp za
# kununurra au
# nikolskoye ru
# tiksi ru
# busselton au
# lata sb
# atuona pf
# hobart au
# bambous virieux mu
# letlhakane bw
# casay ph
# dikson ru
# saint-philippe re
# honiara sb
# nouakchott mr
# thompson ca
# port alfred za
# tasiilaq gl
# haines junction ca
# aklavik ca
# torbay ca
# airai pw
# nishihara jp
# jamestown sh
# sainte-maxime fr
# rikitea pf
# sassandra ci
# goderich sl
# sao joao do piaui br
# jamestown sh
# rikitea pf
# madang pg
# dikson ru
# illoqqortoormiut gl
# yulara au
# albany au
# sitka us
# pevek ru
# coxim br
# gat ly
# yacuiba bo
# matadi cd
# sentyabrskiy ru
# butaritari ki
# port alfred za
# jamestown sh
# coari br
# loikaw mm
# tasiilaq gl
# busselton au
# khatanga ru
# beringovskiy ru
# severo-kurilsk ru
# skarnes no
# birjand ir
# sao miguel do araguaia br
# taolanaro mg
# kargasok ru
# cerro punta pa
# liwale tz
# jamestown sh
# inuvik ca
# lavrentiya ru
# barentsburg sj
# pisco pe
# anapskaya ru
# barrow us
# ushuaia ar
# caravelas br
# saldanha za
# avarua ck
# arraial do cabo br
# new norfolk au
# atuona pf
# hithadhoo mv
# petropavlovsk-kamchatskiy ru
# te anau nz
# saldanha za
# katsuura jp
# bluff nz
# castro cl
# nanortalik gl
# bow island ca
# touros br
# saleaula ws
# rikitea pf
# lavrentiya ru
# pirovskoye ru
# hermanus za
# faya td
# nikolskoye ru
# ilulissat gl
# port alfred za
# vaini to
# general roca ar
# port hardy ca
# hithadhoo mv
# rikitea pf
# hay river ca
# gamba ga
# kruisfontein za
# porto novo cv
# vaini to
# kapaa us
# leninskoye ru
# ushuaia ar
# tuatapere nz
# simmerath de
# jinhua cn
# east london za
# hilo us
# bredasdorp za
# mar del plata ar
# najran sa
# tura ru
# puerto ayora ec
# tubruq ly
# hermanus za
# norman wells ca
# ushuaia ar
# faanui pf

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
cities
# Out:
# ['ituni',
#  'linxia',
#  'samarai',
#  'rikitea',
#  'vaini',
#  'ushuaia',
#  'george',
#  'mahebourg',
#  'illoqqortoormiut',
#  'jamestown',
#  'jiayuguan',
#  'byron bay',
#  'kaitangata',
#  'moron',
#  'hilo',
#  'samalaeulu',
#  'barrow',
#  'hermanus',
#  'cherskiy',
#  'port alfred',
#  'robertsport',
#  'thompson',
#  'katsuura',
#  'dikson',
#  'hobart',
#  'aberdeen',
#  'alice town',
#  'punta arenas',
#  'trelew',
#  'tawkar',
#  'ibara',
#  'coquimbo',
#  'makakilo city',
#  'yellowknife',
#  'diu',
#  'rurrenabaque',
#  'nisia floresta',
#  'sisimiut',
#  'faanui',
#  'mount isa',
#  'marawi',
#  'tuktoyaktuk',
#  'lavrentiya',
#  'kampot',
#  'carutapera',
#  'bonthe',
#  'taolanaro',
#  'porto belo',
#  'rocha',
#  'nagato',
#  'atambua',
#  'albany',
#  'torbay',
#  'baiyin',
#  'cape town',
#  'pevek',
#  'kapaa',
#  'bredasdorp',
#  'busselton',
#  'bonfim',
#  'college',
#  'caravelas',
#  'acarau',
#  'tecoanapa',
#  'camabatela',
#  'banda aceh',
#  'ostrovnoy',
#  'vanimo',
#  'bluff',
#  'ribeira grande',
#  'pedernales',
#  'pisco',
#  'alice springs',
#  'yaan',
#  'esperance',
#  'guerrero negro',
#  'muana',
#  'warqla',
#  'leningradskiy',
#  'saint george',
#  'mareeba',
#  'san patricio',
#  'souillac',
#  'nuuk',
#  'tateyama',
#  'millbrook',
#  'butaritari',
#  'kodiak',
#  'port lincoln',
#  'tura',
#  'portland',
#  'aitape',
#  'apac',
#  'sitka',
#  'goure',
#  'berlevag',
#  'hambantota',
#  'upernavik',
#  'provideniya',
#  'tasiilaq',
#  'westport',
#  'avarua',
#  'touros',
#  'vaitupu',
#  'lakes entrance',
#  'mataura',
#  'tuatapere',
#  'castro',
#  'rovaniemi',
#  'orange cove',
#  'beira',
#  'saint anthony',
#  'samusu',
#  'inhambane',
#  'isangel',
#  'port augusta',
#  'dunedin',
#  'kalaleh',
#  'araouane',
#  'balkanabat',
#  'barentsburg',
#  'nizhneyansk',
#  'nanortalik',
#  'lehigh acres',
#  'okha',
#  'saint-philippe',
#  'jardim',
#  'eureka',
#  'surin',
#  'hailar',
#  'palabuhanratu',
#  'atuona',
#  'srednekolymsk',
#  'karaul',
#  'mullaitivu',
#  'beloha',
#  'mount gambier',
#  'nikolskoye',
#  'korla',
#  'diebougou',
#  'ukiah',
#  'hithadhoo',
#  'puerto ayora',
#  'nouadhibou',
#  'nautla',
#  'bandarbeyla',
#  'haibowan',
#  'qinzhou',
#  'poum',
#  'bethel',
#  'kruisfontein',
#  'majene',
#  'gondanglegi',
#  'new norfolk',
#  'zhuhai',
#  'novaya lyalya',
#  'lebu',
#  'constitucion',
#  'georgetown',
#  'undory',
#  'arraial do cabo',
#  'huarmey',
#  'chase',
#  'severo-yeniseyskiy',
#  'aklavik',
#  'qaanaaq',
#  'ola',
#  'walla walla',
#  'komsomolskiy',
#  'walvis bay',
#  'viedma',
#  'mana',
#  'marcona',
#  'aripuana',
#  'khash',
#  'riyadh',
#  'khatanga',
#  'montepuez',
#  'mys shmidta',
#  'hami',
#  'barra do garcas',
#  'coihaique',
#  'saleaula',
#  'puqi',
#  'port hedland',
#  'mandera',
#  'kahului',
#  'richards bay',
#  'talnakh',
#  'dingle',
#  'victoria',
#  'tiksi',
#  'grand river south east',
#  'port moresby',
#  'baykit',
#  'vostok',
#  'barra patuca',
#  'scarborough',
#  'marsh harbour',
#  'katha',
#  'nantucket',
#  'fortuna',
#  'ugoofaaru',
#  'east london',
#  'brae',
#  'nuevo progreso',
#  'formoso do araguaia',
#  'meulaboh',
#  'adrar',
#  'rundu',
#  'tsihombe',
#  'namatanai',
#  'alihe',
#  'orangeburg',
#  'avera',
#  'half moon bay',
#  'ixtapa',
#  'dubbo',
#  'tukrah',
#  'lata',
#  'cabo san lucas',
#  'qui nhon',
#  'handwara',
#  'salisbury',
#  'sangar',
#  'dongsheng',
#  'maymanak',
#  'amderma',
#  'saskylakh',
#  'panaba',
#  'lolua',
#  'ahipara',
#  'lalibela',
#  'carnarvon',
#  'hun',
#  'chokurdakh',
#  'hwange',
#  'taunsa',
#  'codrington',
#  'tiznit',
#  'karratha',
#  'port macquarie',
#  'umzimvubu',
#  'san cristobal',
#  'goderich',
#  'semey',
#  'wicklow',
#  'necochea',
#  'noumea',
#  'tongchuan',
#  'chuy',
#  'baruun-urt',
#  'ulladulla',
#  'conakry',
#  'cockburn town',
#  'basco',
#  'cap malheureux',
#  'longyearbyen',
#  'zadar',
#  'iquique',
#  'uddevalla',
#  'riberalta',
#  'uniontown',
#  'laguna',
#  'carauari',
#  'sol-iletsk',
#  'kendari',
#  'sarany',
#  'attawapiskat',
#  'flinders',
#  'mayo',
#  'karauzyak',
#  'vallenar',
#  'sao joao da barra',
#  'caluquembe',
#  'xining',
#  'kavieng',
#  'clyde river',
#  'sambava',
#  'sao gabriel da cachoeira',
#  'pavlodar',
#  'belushya guba',
#  'piacabucu',
#  'mahon',
#  'kuznechnoye',
#  'iqaluit',
#  'hamilton',
#  'vanavara',
#  'takhtamygda',
#  'saint-georges',
#  'hasaki',
#  'hope',
#  'tahe',
#  'sao sebastiao',
#  'ayios athanasios',
#  'ilulissat',
#  'pioner',
#  'correntina',
#  'amahai',
#  'geraldton',
#  'luena',
#  'lorengau',
#  'palu',
#  'eustis',
#  'epe',
#  'buraydah',
#  'sadri',
#  'natal',
#  'dombarovskiy',
#  'hovd',
#  'tazovskiy',
#  'matameye',
#  'yomitan',
#  'kirakira',
#  'salinopolis',
#  'los andes',
#  'mtwara',
#  'taltal',
#  'krasnomayskiy',
#  'amancio',
#  'port elizabeth',
#  'havoysund',
#  'umm lajj',
#  'goodyear',
#  'moerai',
#  'ancud',
#  'miandoab',
#  'krasnyye barrikady',
#  'fairbanks',
#  'west plains',
#  'lowicz',
#  'dyadkovskaya',
#  'zabol',
#  'chagda',
#  'kurskaya',
#  'chirgaon',
#  'belmonte',
#  'narsaq',
#  'grindavik',
#  'ngunguru',
#  'kavaratti',
#  'mar del plata',
#  'santa cruz',
#  'alyangula',
#  'bengkulu',
#  'tarakan',
#  'logansport',
#  'naryan-mar',
#  'paradwip',
#  'mastic beach',
#  'escanaba',
#  'tarudant',
#  'pangnirtung',
#  'cristalina',
#  'divicani',
#  'ambilobe',
#  'lahad datu',
#  'hofn',
#  'sur',
#  'dolbeau',
#  'los llanos de aridane',
#  'krasnyy kholm',
#  'rungata',
#  'yunjinghong',
#  'olafsvik',
#  'yumen',
#  'derzhavinsk',
#  'tumannyy',
#  'nalut',
#  'chapais',
#  'benjamin hill',
#  'jimenez',
#  'anadyr',
#  'santa vitoria do palmar',
#  'bacuit',
#  'kisangani',
#  'lar',
#  'laredo',
#  'xuddur',
#  'novo oriente',
#  'salalah',
#  'charagua',
#  'batagay-alyta',
#  'lichinga',
#  'fevralsk',
#  'maxixe',
#  'nakhon thai',
#  'bogashevo',
#  'singaraja',
#  'pundaguitan',
#  'taburi',
#  'quartucciu',
#  'liberia',
#  'newport',
#  'marv dasht',
#  'saldanha',
#  'sao jose da coroa grande',
#  'redmond',
#  'quixada',
#  'kirkwall',
#  'vila velha',
#  'camocim',
#  'luderitz',
#  'lagoa',
#  'fort morgan',
#  'kudirkos naumiestis',
#  'springfield',
#  'ust-tsilma',
#  'bay roberts',
#  'tuscaloosa',
#  'severo-kurilsk',
#  'husavik',
#  'sosva',
#  'ploemeur',
#  'follonica',
#  'tulun',
#  'vila franca do campo',
#  'cidreira',
#  'ishikari',
#  'trincomalee',
#  'broken hill',
#  'atar',
#  'airai',
#  'atikokan',
#  'buala',
#  'chaumont',
#  'port hardy',
#  'muravlenko',
#  'phangnga',
#  'wexford',
#  'saint-augustin',
#  'bolonchen',
#  'trstenik',
#  'thurso',
#  'honningsvag',
#  'kuna',
#  'shenjiamen',
#  'te anau',
#  'cayenne',
#  'hualmay',
#  'nanakuli',
#  'bargal',
#  'ambunti',
#  'yarmouth',
#  'slantsy',
#  'pasni',
#  'imbituba',
#  'srandakan',
#  'tambura',
#  'nieuw amsterdam',
#  'dzaoudzi',
#  'rio hato',
#  'maua',
#  'antofagasta',
#  'terme',
#  'talcahuano',
#  'norman wells',
#  'goundam',
#  'buchanan',
#  'alekseyevka',
#  'aalst',
#  'artyk',
#  'marsa matruh',
#  'kempele',
#  'kazalinsk',
#  'sapao',
#  'puerto narino',
#  'la reforma',
#  'preobrazhenskaya',
#  'petatlan',
#  'inuvik',
#  'obo',
#  'dulce grande',
#  'zdvinsk',
#  'faxinal',
#  'muskegon',
#  'urucara',
#  'mutsamudu',
#  'karamea',
#  'labutta',
#  'derventa',
#  'lompoc',
#  'yulara',
#  'ajdabiya',
#  'butterworth',
#  'visnes',
#  'tigil',
#  'tual',
#  'jumla',
#  'mbalmayo',
#  'ryotsu',
#  'tawau',
#  'hiriyur',
#  'linhares',
#  'aswan',
#  'ketchikan',
#  'polunochnoye',
#  'vila do maio',
#  'bambanglipuro',
#  'wadi maliz',
#  'tonota',
#  'pincher creek',
#  'aksarka',
#  'rorvik',
#  'bathsheba',
#  'mumbwa',
#  'nyurba',
#  'amga',
#  'ust-barguzin',
#  'yerbogachen',
#  'alofi',
#  'tostamaa',
#  'synya',
#  'skreia',
#  'nakamura',
#  'farah',
#  'quelimane',
#  'ust-kuyga',
#  'sungaipenuh',
#  'hudiksvall',
#  'southend-on-sea',
#  'kaoma',
#  'oranjestad',
#  'aksay',
#  'tongliao',
#  'ayan',
#  'kamenka',
#  'great falls',
#  'san pedro',
#  'hattiesburg',
#  'san andres',
#  'kidal',
#  'puerto carreno',
#  'praia da vitoria',
#  'namibe',
#  'karpathos',
#  'kaprijke',
#  'bulgan',
#  'tevriz',
#  'bougouni',
#  'jinchang',
#  'teguise',
#  'kabala',
#  'flin flon',
#  'lumeje',
#  'verkhnetulomskiy',
#  'tuysarkan',
#  'tubruq',
#  'coahuayana',
#  'muros',
#  'zyryanka',
#  'kyren',
#  'itoigawa',
#  'usinsk',
#  'atkinson',
#  'kolokani',
#  'chifeng',
#  'mikhaylovka',
#  'gat',
#  'halalo',
#  'sinnamary',
#  'fort nelson',
#  'aguimes',
#  'mitsamiouli',
#  'lucapa',
#  'bambous virieux',
#  'ewa beach',
#  'makhachkala',
#  'santiago',
#  'daru',
#  'el roble',
#  'nioro',
#  'nicoya',
#  'klaksvik',
#  'high level',
#  'yola',
#  'kaputa',
#  'santiago de cuba',
#  'kashary',
#  'egvekinot',
#  'knysna',
#  'ruteng',
#  'cambrils',
#  'dijkot',
#  'susehri',
#  'kailua',
#  'wanxian',
#  'tortoli',
#  'waingapu',
#  'lulea',
#  'lazaro cardenas',
#  'sentyabrskiy',
#  'maceio',
#  'harer',
#  'makung',
#  'vestmannaeyjar',
#  'pamplona',
#  'luwuk',
#  'roald',
#  'cairns',
#  'maldonado',
#  'sorland',
#  'wangdiphodrang',
#  'tiarei',
#  'nishihara',
#  'rawson',
#  'wulanhaote',
#  'annan',
#  'ponta do sol',
#  'auka',
#  'ranot',
#  'manono',
#  'merritt island',
#  'pacific grove',
#  'najran',
#  'kununurra',
#  'letlhakane',
#  'casay',
#  'honiara',
#  'nouakchott',
#  'haines junction',
#  'sainte-maxime',
#  'sassandra',
#  'sao joao do piaui',
#  'madang',
#  'coxim',
#  'yacuiba',
#  'matadi',
#  'coari',
#  'loikaw',
#  'beringovskiy',
#  'skarnes',
#  'birjand',
#  'sao miguel do araguaia',
#  'kargasok',
#  'cerro punta',
#  'liwale',
#  'anapskaya',
#  'petropavlovsk-kamchatskiy',
#  'bow island',
#  'pirovskoye',
#  'faya',
#  'general roca',
#  'hay river',
#  'gamba',
#  'porto novo',
#  'leninskoye',
#  'simmerath',
#  'jinhua']

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?q="
# + "Boston" + "&appid=" + weather_api_key 
#api.openweathermap.org/data/2.5/weather?q=Boston&appid=6f29b335b92d291f63bc9623d60f81f6
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?q=

# %%
# Create an endpoint URL for a city.
# Testing API key with boston data
city_url = url  + "Boston" + "&appid=" + weather_api_key
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
#This fixes the issue
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + city.replace(" ","+") + "&appid=" + weather_api_key 

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        #city_description = city_weather["weather"]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country
                          #"Current Description": city_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ituni
# City not found. Skipping...
# Processing Record 2 of Set 1 | linxia
# Processing Record 3 of Set 1 | samarai
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | george
# Processing Record 8 of Set 1 | mahebourg
# Processing Record 9 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | jiayuguan
# Processing Record 12 of Set 1 | byron bay
# Processing Record 13 of Set 1 | kaitangata
# Processing Record 14 of Set 1 | moron
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | cherskiy
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | robertsport
# Processing Record 22 of Set 1 | thompson
# Processing Record 23 of Set 1 | katsuura
# Processing Record 24 of Set 1 | dikson
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | aberdeen
# Processing Record 27 of Set 1 | alice town
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | trelew
# Processing Record 30 of Set 1 | tawkar
# City not found. Skipping...
# Processing Record 31 of Set 1 | ibara
# Processing Record 32 of Set 1 | coquimbo
# Processing Record 33 of Set 1 | makakilo city
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | diu
# Processing Record 36 of Set 1 | rurrenabaque
# Processing Record 37 of Set 1 | nisia floresta
# Processing Record 38 of Set 1 | sisimiut
# Processing Record 39 of Set 1 | faanui
# Processing Record 40 of Set 1 | mount isa
# Processing Record 41 of Set 1 | marawi
# Processing Record 42 of Set 1 | tuktoyaktuk
# Processing Record 43 of Set 1 | lavrentiya
# Processing Record 44 of Set 1 | kampot
# Processing Record 45 of Set 1 | carutapera
# Processing Record 46 of Set 1 | bonthe
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | porto belo
# Processing Record 49 of Set 1 | rocha
# Processing Record 50 of Set 1 | nagato
# Processing Record 1 of Set 2 | atambua
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | torbay
# Processing Record 4 of Set 2 | baiyin
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | pevek
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | bredasdorp
# Processing Record 9 of Set 2 | busselton
# Processing Record 10 of Set 2 | bonfim
# Processing Record 11 of Set 2 | college
# Processing Record 12 of Set 2 | caravelas
# Processing Record 13 of Set 2 | acarau
# Processing Record 14 of Set 2 | tecoanapa
# Processing Record 15 of Set 2 | camabatela
# Processing Record 16 of Set 2 | banda aceh
# Processing Record 17 of Set 2 | ostrovnoy
# Processing Record 18 of Set 2 | vanimo
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | ribeira grande
# Processing Record 21 of Set 2 | pedernales
# Processing Record 22 of Set 2 | pisco
# Processing Record 23 of Set 2 | alice springs
# Processing Record 24 of Set 2 | yaan
# Processing Record 25 of Set 2 | esperance
# Processing Record 26 of Set 2 | guerrero negro
# Processing Record 27 of Set 2 | muana
# Processing Record 28 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 2 | leningradskiy
# Processing Record 30 of Set 2 | saint george
# Processing Record 31 of Set 2 | mareeba
# Processing Record 32 of Set 2 | san patricio
# Processing Record 33 of Set 2 | souillac
# Processing Record 34 of Set 2 | nuuk
# Processing Record 35 of Set 2 | tateyama
# Processing Record 36 of Set 2 | millbrook
# Processing Record 37 of Set 2 | butaritari
# Processing Record 38 of Set 2 | kodiak
# Processing Record 39 of Set 2 | port lincoln
# Processing Record 40 of Set 2 | tura
# Processing Record 41 of Set 2 | portland
# Processing Record 42 of Set 2 | aitape
# Processing Record 43 of Set 2 | apac
# Processing Record 44 of Set 2 | sitka
# Processing Record 45 of Set 2 | goure
# Processing Record 46 of Set 2 | berlevag
# Processing Record 47 of Set 2 | hambantota
# Processing Record 48 of Set 2 | upernavik
# Processing Record 49 of Set 2 | provideniya
# Processing Record 50 of Set 2 | tasiilaq
# Processing Record 1 of Set 3 | westport
# Processing Record 2 of Set 3 | avarua
# Processing Record 3 of Set 3 | touros
# Processing Record 4 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 3 | lakes entrance
# Processing Record 6 of Set 3 | mataura
# Processing Record 7 of Set 3 | tuatapere
# Processing Record 8 of Set 3 | castro
# Processing Record 9 of Set 3 | rovaniemi
# Processing Record 10 of Set 3 | orange cove
# Processing Record 11 of Set 3 | beira
# Processing Record 12 of Set 3 | saint anthony
# Processing Record 13 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 3 | inhambane
# Processing Record 15 of Set 3 | isangel
# Processing Record 16 of Set 3 | port augusta
# Processing Record 17 of Set 3 | dunedin
# Processing Record 18 of Set 3 | kalaleh
# Processing Record 19 of Set 3 | araouane
# Processing Record 20 of Set 3 | balkanabat
# Processing Record 21 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 3 | nanortalik
# Processing Record 24 of Set 3 | lehigh acres
# Processing Record 25 of Set 3 | okha
# Processing Record 26 of Set 3 | saint-philippe
# Processing Record 27 of Set 3 | jardim
# Processing Record 28 of Set 3 | eureka
# Processing Record 29 of Set 3 | surin
# Processing Record 30 of Set 3 | hailar
# Processing Record 31 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 3 | atuona
# Processing Record 33 of Set 3 | srednekolymsk
# Processing Record 34 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 3 | mullaitivu
# City not found. Skipping...
# Processing Record 36 of Set 3 | beloha
# Processing Record 37 of Set 3 | mount gambier
# Processing Record 38 of Set 3 | nikolskoye
# Processing Record 39 of Set 3 | korla
# Processing Record 40 of Set 3 | diebougou
# Processing Record 41 of Set 3 | ukiah
# Processing Record 42 of Set 3 | hithadhoo
# Processing Record 43 of Set 3 | puerto ayora
# Processing Record 44 of Set 3 | nouadhibou
# Processing Record 45 of Set 3 | nautla
# Processing Record 46 of Set 3 | bandarbeyla
# Processing Record 47 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 48 of Set 3 | qinzhou
# Processing Record 49 of Set 3 | poum
# Processing Record 50 of Set 3 | bethel
# Processing Record 1 of Set 4 | kruisfontein
# Processing Record 2 of Set 4 | majene
# Processing Record 3 of Set 4 | gondanglegi
# Processing Record 4 of Set 4 | new norfolk
# Processing Record 5 of Set 4 | zhuhai
# Processing Record 6 of Set 4 | novaya lyalya
# Processing Record 7 of Set 4 | lebu
# Processing Record 8 of Set 4 | constitucion
# Processing Record 9 of Set 4 | georgetown
# Processing Record 10 of Set 4 | undory
# Processing Record 11 of Set 4 | arraial do cabo
# Processing Record 12 of Set 4 | huarmey
# Processing Record 13 of Set 4 | chase
# Processing Record 14 of Set 4 | severo-yeniseyskiy
# Processing Record 15 of Set 4 | aklavik
# Processing Record 16 of Set 4 | qaanaaq
# Processing Record 17 of Set 4 | ola
# Processing Record 18 of Set 4 | walla walla
# Processing Record 19 of Set 4 | komsomolskiy
# Processing Record 20 of Set 4 | walvis bay
# Processing Record 21 of Set 4 | viedma
# Processing Record 22 of Set 4 | mana
# Processing Record 23 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 4 | aripuana
# Processing Record 25 of Set 4 | khash
# Processing Record 26 of Set 4 | riyadh
# Processing Record 27 of Set 4 | khatanga
# Processing Record 28 of Set 4 | montepuez
# Processing Record 29 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 4 | hami
# Processing Record 31 of Set 4 | barra do garcas
# Processing Record 32 of Set 4 | coihaique
# Processing Record 33 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 4 | puqi
# Processing Record 35 of Set 4 | port hedland
# Processing Record 36 of Set 4 | mandera
# Processing Record 37 of Set 4 | kahului
# Processing Record 38 of Set 4 | richards bay
# Processing Record 39 of Set 4 | talnakh
# Processing Record 40 of Set 4 | dingle
# Processing Record 41 of Set 4 | victoria
# Processing Record 42 of Set 4 | tiksi
# Processing Record 43 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 4 | port moresby
# Processing Record 45 of Set 4 | baykit
# Processing Record 46 of Set 4 | vostok
# Processing Record 47 of Set 4 | barra patuca
# Processing Record 48 of Set 4 | scarborough
# Processing Record 49 of Set 4 | marsh harbour
# Processing Record 50 of Set 4 | katha
# City not found. Skipping...
# Processing Record 1 of Set 5 | nantucket
# Processing Record 2 of Set 5 | fortuna
# Processing Record 3 of Set 5 | ugoofaaru
# Processing Record 4 of Set 5 | east london
# Processing Record 5 of Set 5 | brae
# Processing Record 6 of Set 5 | nuevo progreso
# Processing Record 7 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 8 of Set 5 | meulaboh
# Processing Record 9 of Set 5 | adrar
# Processing Record 10 of Set 5 | rundu
# Processing Record 11 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 5 | namatanai
# Processing Record 13 of Set 5 | alihe
# Processing Record 14 of Set 5 | orangeburg
# Processing Record 15 of Set 5 | avera
# Processing Record 16 of Set 5 | half moon bay
# Processing Record 17 of Set 5 | ixtapa
# Processing Record 18 of Set 5 | dubbo
# Processing Record 19 of Set 5 | tukrah
# Processing Record 20 of Set 5 | lata
# Processing Record 21 of Set 5 | cabo san lucas
# Processing Record 22 of Set 5 | qui nhon
# Processing Record 23 of Set 5 | handwara
# City not found. Skipping...
# Processing Record 24 of Set 5 | salisbury
# Processing Record 25 of Set 5 | sangar
# Processing Record 26 of Set 5 | dongsheng
# Processing Record 27 of Set 5 | maymanak
# City not found. Skipping...
# Processing Record 28 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 5 | saskylakh
# Processing Record 30 of Set 5 | panaba
# Processing Record 31 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 5 | ahipara
# Processing Record 33 of Set 5 | lalibela
# Processing Record 34 of Set 5 | carnarvon
# Processing Record 35 of Set 5 | hun
# Processing Record 36 of Set 5 | chokurdakh
# Processing Record 37 of Set 5 | hwange
# Processing Record 38 of Set 5 | taunsa
# Processing Record 39 of Set 5 | codrington
# Processing Record 40 of Set 5 | tiznit
# Processing Record 41 of Set 5 | karratha
# Processing Record 42 of Set 5 | port macquarie
# Processing Record 43 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 5 | san cristobal
# Processing Record 45 of Set 5 | goderich
# Processing Record 46 of Set 5 | semey
# Processing Record 47 of Set 5 | wicklow
# Processing Record 48 of Set 5 | necochea
# Processing Record 49 of Set 5 | noumea
# Processing Record 50 of Set 5 | tongchuan
# Processing Record 1 of Set 6 | chuy
# Processing Record 2 of Set 6 | baruun-urt
# Processing Record 3 of Set 6 | ulladulla
# Processing Record 4 of Set 6 | conakry
# Processing Record 5 of Set 6 | cockburn town
# Processing Record 6 of Set 6 | basco
# Processing Record 7 of Set 6 | cap malheureux
# Processing Record 8 of Set 6 | longyearbyen
# Processing Record 9 of Set 6 | zadar
# Processing Record 10 of Set 6 | iquique
# Processing Record 11 of Set 6 | uddevalla
# Processing Record 12 of Set 6 | riberalta
# Processing Record 13 of Set 6 | uniontown
# Processing Record 14 of Set 6 | laguna
# Processing Record 15 of Set 6 | carauari
# Processing Record 16 of Set 6 | sol-iletsk
# Processing Record 17 of Set 6 | kendari
# Processing Record 18 of Set 6 | sarany
# Processing Record 19 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 6 | flinders
# Processing Record 21 of Set 6 | mayo
# Processing Record 22 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 23 of Set 6 | vallenar
# Processing Record 24 of Set 6 | sao joao da barra
# Processing Record 25 of Set 6 | caluquembe
# Processing Record 26 of Set 6 | xining
# Processing Record 27 of Set 6 | kavieng
# Processing Record 28 of Set 6 | clyde river
# Processing Record 29 of Set 6 | sambava
# Processing Record 30 of Set 6 | sao gabriel da cachoeira
# Processing Record 31 of Set 6 | pavlodar
# Processing Record 32 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 6 | piacabucu
# Processing Record 34 of Set 6 | mahon
# Processing Record 35 of Set 6 | kuznechnoye
# Processing Record 36 of Set 6 | iqaluit
# Processing Record 37 of Set 6 | hamilton
# Processing Record 38 of Set 6 | vanavara
# Processing Record 39 of Set 6 | takhtamygda
# Processing Record 40 of Set 6 | saint-georges
# Processing Record 41 of Set 6 | hasaki
# Processing Record 42 of Set 6 | hope
# Processing Record 43 of Set 6 | tahe
# Processing Record 44 of Set 6 | sao sebastiao
# Processing Record 45 of Set 6 | ayios athanasios
# Processing Record 46 of Set 6 | ilulissat
# Processing Record 47 of Set 6 | pioner
# Processing Record 48 of Set 6 | correntina
# Processing Record 49 of Set 6 | amahai
# Processing Record 50 of Set 6 | geraldton
# Processing Record 1 of Set 7 | luena
# Processing Record 2 of Set 7 | lorengau
# Processing Record 3 of Set 7 | palu
# Processing Record 4 of Set 7 | eustis
# Processing Record 5 of Set 7 | epe
# Processing Record 6 of Set 7 | buraydah
# Processing Record 7 of Set 7 | sadri
# Processing Record 8 of Set 7 | natal
# Processing Record 9 of Set 7 | dombarovskiy
# Processing Record 10 of Set 7 | hovd
# Processing Record 11 of Set 7 | tazovskiy
# Processing Record 12 of Set 7 | matameye
# City not found. Skipping...
# Processing Record 13 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 14 of Set 7 | kirakira
# Processing Record 15 of Set 7 | salinopolis
# Processing Record 16 of Set 7 | los andes
# Processing Record 17 of Set 7 | mtwara
# Processing Record 18 of Set 7 | taltal
# Processing Record 19 of Set 7 | krasnomayskiy
# Processing Record 20 of Set 7 | amancio
# City not found. Skipping...
# Processing Record 21 of Set 7 | port elizabeth
# Processing Record 22 of Set 7 | havoysund
# Processing Record 23 of Set 7 | umm lajj
# Processing Record 24 of Set 7 | goodyear
# Processing Record 25 of Set 7 | moerai
# Processing Record 26 of Set 7 | ancud
# Processing Record 27 of Set 7 | miandoab
# Processing Record 28 of Set 7 | krasnyye barrikady
# Processing Record 29 of Set 7 | fairbanks
# Processing Record 30 of Set 7 | west plains
# Processing Record 31 of Set 7 | lowicz
# Processing Record 32 of Set 7 | dyadkovskaya
# City not found. Skipping...
# Processing Record 33 of Set 7 | zabol
# Processing Record 34 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 35 of Set 7 | kurskaya
# Processing Record 36 of Set 7 | chirgaon
# Processing Record 37 of Set 7 | belmonte
# Processing Record 38 of Set 7 | narsaq
# Processing Record 39 of Set 7 | grindavik
# Processing Record 40 of Set 7 | ngunguru
# Processing Record 41 of Set 7 | kavaratti
# Processing Record 42 of Set 7 | mar del plata
# Processing Record 43 of Set 7 | santa cruz
# Processing Record 44 of Set 7 | alyangula
# Processing Record 45 of Set 7 | bengkulu
# Processing Record 46 of Set 7 | tarakan
# Processing Record 47 of Set 7 | logansport
# Processing Record 48 of Set 7 | naryan-mar
# Processing Record 49 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 50 of Set 7 | mastic beach
# Processing Record 1 of Set 8 | escanaba
# Processing Record 2 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 3 of Set 8 | pangnirtung
# Processing Record 4 of Set 8 | cristalina
# Processing Record 5 of Set 8 | divicani
# Processing Record 6 of Set 8 | ambilobe
# Processing Record 7 of Set 8 | lahad datu
# Processing Record 8 of Set 8 | hofn
# Processing Record 9 of Set 8 | sur
# Processing Record 10 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 11 of Set 8 | los llanos de aridane
# Processing Record 12 of Set 8 | krasnyy kholm
# Processing Record 13 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 8 | yunjinghong
# City not found. Skipping...
# Processing Record 15 of Set 8 | olafsvik
# Processing Record 16 of Set 8 | yumen
# Processing Record 17 of Set 8 | derzhavinsk
# Processing Record 18 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 8 | nalut
# Processing Record 20 of Set 8 | chapais
# Processing Record 21 of Set 8 | benjamin hill
# Processing Record 22 of Set 8 | jimenez
# Processing Record 23 of Set 8 | anadyr
# Processing Record 24 of Set 8 | santa vitoria do palmar
# Processing Record 25 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 26 of Set 8 | kisangani
# Processing Record 27 of Set 8 | lar
# Processing Record 28 of Set 8 | laredo
# Processing Record 29 of Set 8 | xuddur
# Processing Record 30 of Set 8 | novo oriente
# Processing Record 31 of Set 8 | salalah
# Processing Record 32 of Set 8 | charagua
# Processing Record 33 of Set 8 | batagay-alyta
# Processing Record 34 of Set 8 | lichinga
# Processing Record 35 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 36 of Set 8 | maxixe
# Processing Record 37 of Set 8 | nakhon thai
# Processing Record 38 of Set 8 | bogashevo
# Processing Record 39 of Set 8 | singaraja
# Processing Record 40 of Set 8 | pundaguitan
# Processing Record 41 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 42 of Set 8 | quartucciu
# Processing Record 43 of Set 8 | liberia
# Processing Record 44 of Set 8 | newport
# Processing Record 45 of Set 8 | marv dasht
# City not found. Skipping...
# Processing Record 46 of Set 8 | saldanha
# Processing Record 47 of Set 8 | sao jose da coroa grande
# Processing Record 48 of Set 8 | redmond
# Processing Record 49 of Set 8 | quixada
# Processing Record 50 of Set 8 | kirkwall
# Processing Record 1 of Set 9 | vila velha
# Processing Record 2 of Set 9 | camocim
# Processing Record 3 of Set 9 | luderitz
# Processing Record 4 of Set 9 | lagoa
# Processing Record 5 of Set 9 | fort morgan
# Processing Record 6 of Set 9 | kudirkos naumiestis
# Processing Record 7 of Set 9 | springfield
# Processing Record 8 of Set 9 | ust-tsilma
# Processing Record 9 of Set 9 | bay roberts
# Processing Record 10 of Set 9 | tuscaloosa
# Processing Record 11 of Set 9 | severo-kurilsk
# Processing Record 12 of Set 9 | husavik
# Processing Record 13 of Set 9 | sosva
# Processing Record 14 of Set 9 | ploemeur
# Processing Record 15 of Set 9 | follonica
# Processing Record 16 of Set 9 | tulun
# Processing Record 17 of Set 9 | vila franca do campo
# Processing Record 18 of Set 9 | cidreira
# Processing Record 19 of Set 9 | ishikari
# Processing Record 20 of Set 9 | trincomalee
# Processing Record 21 of Set 9 | broken hill
# Processing Record 22 of Set 9 | atar
# Processing Record 23 of Set 9 | airai
# Processing Record 24 of Set 9 | atikokan
# Processing Record 25 of Set 9 | buala
# Processing Record 26 of Set 9 | chaumont
# Processing Record 27 of Set 9 | port hardy
# Processing Record 28 of Set 9 | muravlenko
# Processing Record 29 of Set 9 | phangnga
# Processing Record 30 of Set 9 | wexford
# Processing Record 31 of Set 9 | saint-augustin
# Processing Record 32 of Set 9 | bolonchen
# City not found. Skipping...
# Processing Record 33 of Set 9 | trstenik
# Processing Record 34 of Set 9 | thurso
# Processing Record 35 of Set 9 | honningsvag
# Processing Record 36 of Set 9 | kuna
# Processing Record 37 of Set 9 | shenjiamen
# Processing Record 38 of Set 9 | te anau
# Processing Record 39 of Set 9 | cayenne
# Processing Record 40 of Set 9 | hualmay
# Processing Record 41 of Set 9 | nanakuli
# Processing Record 42 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 9 | ambunti
# Processing Record 44 of Set 9 | yarmouth
# Processing Record 45 of Set 9 | slantsy
# Processing Record 46 of Set 9 | pasni
# Processing Record 47 of Set 9 | imbituba
# Processing Record 48 of Set 9 | srandakan
# Processing Record 49 of Set 9 | tambura
# Processing Record 50 of Set 9 | nieuw amsterdam
# Processing Record 1 of Set 10 | dzaoudzi
# Processing Record 2 of Set 10 | rio hato
# Processing Record 3 of Set 10 | maua
# Processing Record 4 of Set 10 | antofagasta
# Processing Record 5 of Set 10 | terme
# Processing Record 6 of Set 10 | talcahuano
# Processing Record 7 of Set 10 | norman wells
# Processing Record 8 of Set 10 | goundam
# Processing Record 9 of Set 10 | buchanan
# Processing Record 10 of Set 10 | alekseyevka
# Processing Record 11 of Set 10 | aalst
# Processing Record 12 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 13 of Set 10 | marsa matruh
# Processing Record 14 of Set 10 | kempele
# Processing Record 15 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 10 | sapao
# City not found. Skipping...
# Processing Record 17 of Set 10 | puerto narino
# Processing Record 18 of Set 10 | la reforma
# Processing Record 19 of Set 10 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 20 of Set 10 | petatlan
# Processing Record 21 of Set 10 | inuvik
# Processing Record 22 of Set 10 | obo
# Processing Record 23 of Set 10 | dulce grande
# Processing Record 24 of Set 10 | zdvinsk
# Processing Record 25 of Set 10 | faxinal
# Processing Record 26 of Set 10 | muskegon
# Processing Record 27 of Set 10 | urucara
# Processing Record 28 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 29 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 30 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 31 of Set 10 | derventa
# Processing Record 32 of Set 10 | lompoc
# Processing Record 33 of Set 10 | yulara
# Processing Record 34 of Set 10 | ajdabiya
# Processing Record 35 of Set 10 | butterworth
# Processing Record 36 of Set 10 | visnes
# Processing Record 37 of Set 10 | tigil
# Processing Record 38 of Set 10 | tual
# Processing Record 39 of Set 10 | jumla
# Processing Record 40 of Set 10 | mbalmayo
# Processing Record 41 of Set 10 | ryotsu
# Processing Record 42 of Set 10 | tawau
# Processing Record 43 of Set 10 | hiriyur
# Processing Record 44 of Set 10 | linhares
# Processing Record 45 of Set 10 | aswan
# Processing Record 46 of Set 10 | ketchikan
# Processing Record 47 of Set 10 | polunochnoye
# Processing Record 48 of Set 10 | vila do maio
# Processing Record 49 of Set 10 | bambanglipuro
# Processing Record 50 of Set 10 | wadi maliz
# Processing Record 1 of Set 11 | tonota
# Processing Record 2 of Set 11 | pincher creek
# Processing Record 3 of Set 11 | aksarka
# Processing Record 4 of Set 11 | rorvik
# Processing Record 5 of Set 11 | bathsheba
# Processing Record 6 of Set 11 | mumbwa
# Processing Record 7 of Set 11 | nyurba
# Processing Record 8 of Set 11 | amga
# Processing Record 9 of Set 11 | ust-barguzin
# Processing Record 10 of Set 11 | yerbogachen
# Processing Record 11 of Set 11 | alofi
# Processing Record 12 of Set 11 | tostamaa
# City not found. Skipping...
# Processing Record 13 of Set 11 | synya
# Processing Record 14 of Set 11 | skreia
# Processing Record 15 of Set 11 | nakamura
# Processing Record 16 of Set 11 | farah
# Processing Record 17 of Set 11 | quelimane
# Processing Record 18 of Set 11 | ust-kuyga
# Processing Record 19 of Set 11 | sungaipenuh
# Processing Record 20 of Set 11 | hudiksvall
# Processing Record 21 of Set 11 | southend-on-sea
# Processing Record 22 of Set 11 | kaoma
# Processing Record 23 of Set 11 | oranjestad
# Processing Record 24 of Set 11 | aksay
# Processing Record 25 of Set 11 | tongliao
# Processing Record 26 of Set 11 | ayan
# Processing Record 27 of Set 11 | kamenka
# Processing Record 28 of Set 11 | great falls
# Processing Record 29 of Set 11 | san pedro
# Processing Record 30 of Set 11 | hattiesburg
# Processing Record 31 of Set 11 | san andres
# Processing Record 32 of Set 11 | kidal
# Processing Record 33 of Set 11 | puerto carreno
# Processing Record 34 of Set 11 | praia da vitoria
# Processing Record 35 of Set 11 | namibe
# Processing Record 36 of Set 11 | karpathos
# Processing Record 37 of Set 11 | kaprijke
# Processing Record 38 of Set 11 | bulgan
# Processing Record 39 of Set 11 | tevriz
# Processing Record 40 of Set 11 | bougouni
# Processing Record 41 of Set 11 | jinchang
# Processing Record 42 of Set 11 | teguise
# Processing Record 43 of Set 11 | kabala
# Processing Record 44 of Set 11 | flin flon
# Processing Record 45 of Set 11 | lumeje
# Processing Record 46 of Set 11 | verkhnetulomskiy
# Processing Record 47 of Set 11 | tuysarkan
# City not found. Skipping...
# Processing Record 48 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 49 of Set 11 | coahuayana
# Processing Record 50 of Set 11 | muros
# Processing Record 1 of Set 12 | zyryanka
# Processing Record 2 of Set 12 | kyren
# Processing Record 3 of Set 12 | itoigawa
# Processing Record 4 of Set 12 | usinsk
# Processing Record 5 of Set 12 | atkinson
# Processing Record 6 of Set 12 | kolokani
# Processing Record 7 of Set 12 | chifeng
# Processing Record 8 of Set 12 | mikhaylovka
# Processing Record 9 of Set 12 | gat
# Processing Record 10 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 12 | sinnamary
# Processing Record 12 of Set 12 | fort nelson
# Processing Record 13 of Set 12 | aguimes
# Processing Record 14 of Set 12 | mitsamiouli
# Processing Record 15 of Set 12 | lucapa
# Processing Record 16 of Set 12 | bambous virieux
# Processing Record 17 of Set 12 | ewa beach
# Processing Record 18 of Set 12 | makhachkala
# Processing Record 19 of Set 12 | santiago
# Processing Record 20 of Set 12 | daru
# Processing Record 21 of Set 12 | el roble
# Processing Record 22 of Set 12 | nioro
# Processing Record 23 of Set 12 | nicoya
# Processing Record 24 of Set 12 | klaksvik
# Processing Record 25 of Set 12 | high level
# Processing Record 26 of Set 12 | yola
# Processing Record 27 of Set 12 | kaputa
# Processing Record 28 of Set 12 | santiago de cuba
# Processing Record 29 of Set 12 | kashary
# Processing Record 30 of Set 12 | egvekinot
# Processing Record 31 of Set 12 | knysna
# Processing Record 32 of Set 12 | ruteng
# Processing Record 33 of Set 12 | cambrils
# Processing Record 34 of Set 12 | dijkot
# Processing Record 35 of Set 12 | susehri
# Processing Record 36 of Set 12 | kailua
# Processing Record 37 of Set 12 | wanxian
# Processing Record 38 of Set 12 | tortoli
# Processing Record 39 of Set 12 | waingapu
# Processing Record 40 of Set 12 | lulea
# Processing Record 41 of Set 12 | lazaro cardenas
# Processing Record 42 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 12 | maceio
# Processing Record 44 of Set 12 | harer
# Processing Record 45 of Set 12 | makung
# City not found. Skipping...
# Processing Record 46 of Set 12 | vestmannaeyjar
# Processing Record 47 of Set 12 | pamplona
# Processing Record 48 of Set 12 | luwuk
# Processing Record 49 of Set 12 | roald
# Processing Record 50 of Set 12 | cairns
# Processing Record 1 of Set 13 | maldonado
# Processing Record 2 of Set 13 | sorland
# Processing Record 3 of Set 13 | wangdiphodrang
# City not found. Skipping...
# Processing Record 4 of Set 13 | tiarei
# Processing Record 5 of Set 13 | nishihara
# Processing Record 6 of Set 13 | rawson
# Processing Record 7 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 8 of Set 13 | annan
# Processing Record 9 of Set 13 | ponta do sol
# Processing Record 10 of Set 13 | auka
# Processing Record 11 of Set 13 | ranot
# Processing Record 12 of Set 13 | manono
# Processing Record 13 of Set 13 | merritt island
# Processing Record 14 of Set 13 | pacific grove
# Processing Record 15 of Set 13 | najran
# Processing Record 16 of Set 13 | kununurra
# Processing Record 17 of Set 13 | letlhakane
# Processing Record 18 of Set 13 | casay
# Processing Record 19 of Set 13 | honiara
# Processing Record 20 of Set 13 | nouakchott
# Processing Record 21 of Set 13 | haines junction
# Processing Record 22 of Set 13 | sainte-maxime
# Processing Record 23 of Set 13 | sassandra
# Processing Record 24 of Set 13 | sao joao do piaui
# Processing Record 25 of Set 13 | madang
# Processing Record 26 of Set 13 | coxim
# Processing Record 27 of Set 13 | yacuiba
# Processing Record 28 of Set 13 | matadi
# Processing Record 29 of Set 13 | coari
# Processing Record 30 of Set 13 | loikaw
# Processing Record 31 of Set 13 | beringovskiy
# Processing Record 32 of Set 13 | skarnes
# Processing Record 33 of Set 13 | birjand
# Processing Record 34 of Set 13 | sao miguel do araguaia
# Processing Record 35 of Set 13 | kargasok
# Processing Record 36 of Set 13 | cerro punta
# Processing Record 37 of Set 13 | liwale
# Processing Record 38 of Set 13 | anapskaya
# Processing Record 39 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 13 | bow island
# Processing Record 41 of Set 13 | pirovskoye
# Processing Record 42 of Set 13 | faya
# Processing Record 43 of Set 13 | general roca
# Processing Record 44 of Set 13 | hay river
# Processing Record 45 of Set 13 | gamba
# Processing Record 46 of Set 13 | porto novo
# Processing Record 47 of Set 13 | leninskoye
# Processing Record 48 of Set 13 | simmerath
# Processing Record 49 of Set 13 | jinhua
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 588

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Linxia  35.6003  103.2064    267.27        82          94        0.42
# 1    Samarai -10.6167  150.6667    300.91        74         100        2.92
# 2    Rikitea -23.1203 -134.9692    299.90        69          33        5.30
# 3      Vaini -21.2000 -175.2000    299.15        89          75        3.09
# 4    Ushuaia -54.8000  -68.3000    280.15        61          75       11.83
# 5     George -33.9630   22.4617    292.15        94          75        2.06
# 6  Mahebourg -20.4081   57.7000    297.15        83          20        3.09
# 7  Jamestown  42.0970  -79.2353    275.37        93          90        5.24
# 8  Jiayuguan  39.8167   98.3000    264.97        79          90        1.96
# 9  Byron Bay -28.6500  153.6167    295.15        94          14        2.69
#
#   Country
# 0      CN
# 1      PG
# 2      PF
# 3      TO
# 4      AR
# 5      ZA
# 6      MU
# 7      US
# 8      CN
# 9      AU

# %%
new_column_order = ["City", "Country","Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#       City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Linxia      CN  35.6003  103.2064    267.27        82          94
# 1  Samarai      PG -10.6167  150.6667    300.91        74         100
# 2  Rikitea      PF -23.1203 -134.9692    299.90        69          33
# 3    Vaini      TO -21.2000 -175.2000    299.15        89          75
# 4  Ushuaia      AR -54.8000  -68.3000    280.15        61          75
#
#    Wind Speed
# 0        0.42
# 1        2.92
# 2        5.30
# 3        3.09
# 4       11.83

# %%
# Create the output file (CSV).
output_data_file = "cities_d1.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
